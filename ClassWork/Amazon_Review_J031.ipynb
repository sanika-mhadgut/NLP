# %% [markdown]
# <a href="https://colab.research.google.com/github/sanika-mhadgut/NLP/blob/master/Amazon_Review_J031.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Name : Sanika Mhadgut
# #Branch : Btech Data Science Sem 6
# #Roll No: J031

# %%
import pandas as pd
import json
from collections import Counter
url = "http://snap.stanford.edu/data/amazon/productGraph/categoryFiles/reviews_Office_Products_5.json.gz"

# %%
r = pd.read_json(url,lines=True)

# %%
#function which splits the words in a text paragraph and returns counter of occurrence of each individual word as dictionary
def custom_func(text):
  return Counter(text.split())

# %%
df1 = r.copy()

# %%
df1['reviewCounter'] = df1['reviewText'].apply(lambda x:custom_func(x))

# %%
df1['reviewCounter'][1]
# Out:
# Counter({'!': 1,
#          '"The': 1,
#          '"fix': 1,
#          '"gold"': 2,
#          '"golden': 1,
#          '"portable"': 1,
#          '"retro"': 1,
#          '&': 3,
#          "'81": 1,
#          '(2004': 1,
#          '(2006': 1,
#          '(December': 1,
#          '(and': 1,
#          ',it': 1,
#          '-': 6,
#          '1,': 1,
#          '11C,': 1,
#          '12C': 4,
#          '12Cs,': 1,
#          '12c': 4,
#          '15': 1,
#          '1Oth': 1,
#          '1st': 1,
#          '2004.It': 1,
#          '2007),': 1,
#          '2031,': 1,
#          '25th': 2,
#          '3rd': 1,
#          '4': 1,
#          '50th': 3,
#          'A': 1,
#          'ALL': 1,
#          'ALWAYS': 1,
#          "AREN'T": 1,
#          'According': 1,
#          'Amazon': 1,
#          'Amazon.com,': 1,
#          'Anniversary': 4,
#          'BELATED': 1,
#          'BENCHMARKING': 1,
#          'BETTER': 1,
#          'BROKEN,': 1,
#          'Based': 1,
#          'By': 1,
#          'COULD': 1,
#          'CUSTOMERS!': 1,
#          'DISCONTINUE': 1,
#          'DO': 1,
#          "DON't": 1,
#          'Edition': 1,
#          'Especially': 1,
#          'FIX': 1,
#          'FOR': 1,
#          'GOLD': 7,
#          'GOLD.': 1,
#          'GOLDEN': 1,
#          'Gold.': 1,
#          'HP': 22,
#          "HP's": 2,
#          'HP,': 2,
#          'HP...GOLDEN': 1,
#          'HP10Bs': 1,
#          'HP10bII': 1,
#          'HP12C': 18,
#          "HP12C's": 1,
#          'HP12C,': 1,
#          'HP12C.': 1,
#          'HP12c': 3,
#          'HP12cP)': 1,
#          'HP12cPA).To': 1,
#          'HP12cPAE': 1,
#          'HP12cPlatinum': 3,
#          'HP17Bs,': 1,
#          'HP17bII+': 1,
#          'Hewlett-Packard': 2,
#          'However,': 1,
#          'I': 7,
#          'IBM': 2,
#          'ICONIC': 1,
#          'IF': 1,
#          'II': 1,
#          'II.GOLDEN': 1,
#          'III': 1,
#          'INDUSTRY': 1,
#          'IS': 2,
#          'IT': 2,
#          'ITSELF': 1,
#          'IV': 1,
#          'If': 2,
#          'Just': 1,
#          'LINE': 1,
#          'LISTEN': 1,
#          'Lenovo.GOLDEN': 1,
#          'MANUFACTURING': 1,
#          'NEVER': 1,
#          'NOT': 1,
#          'OBSOLETE.GOLDEN': 1,
#          'OF': 1,
#          'ONLY': 1,
#          'OUTSOURCE': 1,
#          'OWN': 1,
#          'PC': 1,
#          'PRODUCT': 4,
#          'Platinium,': 1,
#          'Platinum': 2,
#          'Platiunum': 1,
#          'Please': 1,
#          'QUALITY.': 1,
#          'READ': 1,
#          'REVIEW?': 1,
#          'RPN)': 1,
#          'RULE': 6,
#          'RULES': 1,
#          'SELLS': 1,
#          'SOMEONE': 1,
#          'STANDARD': 1,
#          'STILL': 1,
#          'So': 1,
#          'THE': 4,
#          'THIS': 2,
#          'TO': 2,
#          'The': 1,
#          'ThinkCentres.Since': 1,
#          'ThinkPads': 1,
#          'This': 1,
#          'To': 1,
#          'V': 1,
#          'VI': 1,
#          'WHICH': 1,
#          'WHO': 1,
#          'WHY': 1,
#          'With': 1,
#          'YOUR': 3,
#          'a': 12,
#          'about': 3,
#          'above.To': 1,
#          'action.The': 1,
#          'after': 3,
#          'alike.': 1,
#          'all': 2,
#          'almost': 1,
#          'always': 3,
#          'am': 2,
#          'amusing': 1,
#          'an': 1,
#          'and': 30,
#          'anniversary': 3,
#          'any': 2,
#          'ardent': 1,
#          'as': 2,
#          'ask': 1,
#          'at': 2,
#          'attempt': 1,
#          'be': 8,
#          'bear': 1,
#          'bearer': 1,
#          'bearer.': 1,
#          'because': 1,
#          'been': 1,
#          'before': 1,
#          'being': 1,
#          'best': 2,
#          'boy"': 1,
#          'brandname': 2,
#          'built': 1,
#          'burying': 1,
#          'business': 6,
#          'by': 6,
#          'cPs': 1,
#          'calculator': 8,
#          'calculators': 1,
#          'calculators,': 1,
#          'case,': 1,
#          'challenge': 1,
#          'charge': 1,
#          'come': 1,
#          'companion': 1,
#          'computer': 1,
#          'computers': 2,
#          'continued': 1,
#          'continuing': 1,
#          'could': 1,
#          'customer': 1,
#          'customer,': 1,
#          "customers.Don't": 1,
#          'customers.GOLDEN': 1,
#          'date': 1,
#          'day': 3,
#          'decide': 1,
#          'desktops': 1,
#          'dethroned': 1,
#          'did': 1,
#          'differentiating': 1,
#          'disappeared': 1,
#          'disappears': 1,
#          'disappointing': 1,
#          'discontinue': 1,
#          'discontinuing': 1,
#          'does': 1,
#          'doubt': 1,
#          'doubt,': 1,
#          'effort': 1,
#          'electronic': 2,
#          'engraved': 1,
#          'especially': 1,
#          'even': 1,
#          'ever': 1,
#          'ever.': 1,
#          'ever.As': 1,
#          'exit': 1,
#          'expected': 1,
#          'factor': 1,
#          'fair,': 1,
#          'fan': 2,
#          'fan.': 1,
#          'fans': 2,
#          'fans,': 1,
#          'fans.': 1,
#          'fans.For': 1,
#          'fans.Looking': 1,
#          'faster': 1,
#          'feel': 1,
#          'field': 1,
#          'finance-business': 1,
#          'financial': 3,
#          'find': 1,
#          'first': 1,
#          'following': 1,
#          'for': 5,
#          'force': 1,
#          'form': 2,
#          'forward,': 1,
#          'four': 1,
#          'frank': 1,
#          'from': 4,
#          'frustrating': 1,
#          'functions.IMHO,': 1,
#          'futile': 1,
#          'generation': 1,
#          'genuine': 1,
#          'go.Even': 1,
#          'gold': 2,
#          'golden': 2,
#          'gospel': 1,
#          'guarded': 1,
#          'had': 4,
#          'handheld': 2,
#          'handy': 1,
#          'happen': 1,
#          'happened': 1,
#          'has': 2,
#          'have': 2,
#          'heldheld': 2,
#          'here,': 1,
#          'highest': 1,
#          'hit': 1,
#          'hits': 1,
#          'home': 1,
#          'however,': 1,
#          'if': 4,
#          'immediately': 1,
#          'in': 12,
#          'including': 1,
#          'indeed': 1,
#          'indispensable': 1,
#          'infringed': 1,
#          'intention': 1,
#          'into': 1,
#          'is': 17,
#          'it': 7,
#          'its': 16,
#          'jump': 1,
#          'just': 2,
#          'know': 1,
#          'least': 1,
#          'let': 1,
#          'like': 2,
#          'line': 2,
#          'line,': 1,
#          'line-it': 1,
#          'listen': 1,
#          'listening': 1,
#          'logo,': 1,
#          'longest': 1,
#          'look': 1,
#          'love': 1,
#          'lucrative': 1,
#          'major': 1,
#          'majority': 2,
#          'mark': 2,
#          'market': 1,
#          'matured': 1,
#          'may': 1,
#          'milestone': 1,
#          'million': 1,
#          'mind': 1,
#          'missing': 1,
#          'model': 2,
#          'models': 2,
#          'moves': 1,
#          'my': 3,
#          'myself,': 1,
#          'name': 2,
#          'needs': 1,
#          'nerd': 1,
#          'nice': 2,
#          'no': 1,
#          'non-techkie': 1,
#          'none': 1,
#          'not': 7,
#          'now': 1,
#          'now,': 1,
#          'obliged': 1,
#          'observe': 1,
#          'occasion,': 2,
#          'of': 24,
#          'offered': 1,
#          'old': 2,
#          'on': 6,
#          'on.Anyone': 1,
#          'only': 1,
#          'opportunity': 1,
#          'or': 2,
#          'original': 1,
#          'other': 2,
#          'out': 1,
#          'outdone': 1,
#          'ower': 1,
#          'own': 3,
#          'owners': 2,
#          'owners,': 1,
#          'paramount': 1,
#          'part': 1,
#          'personal': 2,
#          'place': 1,
#          'please': 1,
#          'portable': 1,
#          'powers': 1,
#          'praising': 1,
#          'price': 2,
#          'probably': 2,
#          'product': 5,
#          'product,': 2,
#          'production': 1,
#          'products': 1,
#          'products,': 1,
#          'professionals': 1,
#          'proposition.': 1,
#          'proven': 2,
#          'puzzling': 1,
#          'quality': 3,
#          'range': 1,
#          'realize': 1,
#          'realized': 1,
#          'reasoning,': 1,
#          'reckon': 1,
#          'release': 1,
#          'release,': 2,
#          'remaining': 1,
#          'remains': 1,
#          'remaking': 1,
#          'reminder': 1,
#          'replacing': 1,
#          'respect!': 1,
#          'retire"': 1,
#          'retired.As': 1,
#          'right': 1,
#          'right.': 1,
#          'rightful': 1,
#          'rights': 1,
#          'rise,': 1,
#          'rival': 1,
#          'rivals': 1,
#          'rule': 1,
#          'rules': 2,
#          'run': 2,
#          'same': 1,
#          'satisfied': 1,
#          'scientific': 1,
#          'see': 2,
#          'seems': 1,
#          'segment.': 1,
#          'segment.The': 1,
#          'selling': 2,
#          'series': 1,
#          'series,': 1,
#          'serious': 1,
#          'seriously': 1,
#          'share': 1,
#          'sharing': 1,
#          'should': 3,
#          'siblings': 1,
#          'silver': 2,
#          'since': 3,
#          'software': 1,
#          'sofware': 1,
#          'sold': 1,
#          'sold,': 1,
#          'solution,': 1,
#          'somewhat': 1,
#          'speculate': 1,
#          'spent': 1,
#          'spotted': 1,
#          'standard': 4,
#          'standard.': 1,
#          'still': 1,
#          'students': 1,
#          'successors': 3,
#          'survived': 1,
#          'surviving': 1,
#          'synonymous': 1,
#          'taken': 1,
#          'team.': 1,
#          'terms': 1,
#          'tested': 2,
#          'testimony': 2,
#          'than': 2,
#          'that': 7,
#          'the': 67,
#          'their': 2,
#          'they': 2,
#          'this': 10,
#          'three': 3,
#          'thumb': 1,
#          'time': 1,
#          'to': 14,
#          'treat': 1,
#          'truly': 1,
#          'two': 2,
#          'ultimate': 3,
#          'unchanged': 1,
#          'up': 1,
#          'upgrades': 1,
#          'upmost': 1,
#          'user': 1,
#          'users': 1,
#          'users.GOLDEN': 1,
#          'users.To': 1,
#          'using': 1,
#          'versions': 1,
#          'very': 3,
#          'view': 1,
#          'views': 2,
#          'was': 1,
#          'were': 1,
#          'when': 2,
#          'which': 2,
#          'why': 1,
#          'with': 6,
#          'workhorse': 2,
#          'workhorse,': 1,
#          'works': 1,
#          'would': 10,
#          'year': 2,
#          'years': 1,
#          'your': 1})
